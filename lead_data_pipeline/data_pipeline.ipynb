# %%
import sys
import os
import pandas as pd
from data_pipeline import clean_text, clean_email, clean_phone, clean_website, normalize_province

# Load dirty data
# BASE_DIR = "/home/isaie/Projects/Lyyvora-outreach-core-service"
# INPUT_FILE = os.path.join(BASE_DIR, "data", "mock_data_sets", "mock_dirty_data.csv")
df = pd.read_csv("/home/isaie/Projects/Lyyvora-outreach-core-service/data/mock_data_sets/mock_dirty_data.csv")

# STEP 0. Display original, uncleaned dataset
df.head(10)
# Out:
#                  clinic_name         specialty         city province  \
# 0  Quebec City Medical Group   Family Medicine  Québec City       QC
# 1        Québec City Medical   Family Practice  Quebec City   Quebec
# 2       Dr. O'Brien's Clinic  General Practice   St. John's       NL
# 3                        NaN   Massage Therapy          NaN      NaN
# 4     Duplicate Phone Test 1        Cardiology       London       ON
# 5     Duplicate Phone Test 2         Neurology       London  Ontario
# 6     Special Char's Clinic!       Urgent Care    Kitchener       ON
# 7        Whitespace   Clinic     Ophthalmology     Waterloo       ON
# 8           UPPERCASE CLINIC               ENT     HAMILTON       ON
# 9           lowercase clinic          oncology       guelph       on
#
#           phone                   website                       email  \
# 0  418-555-7766          www.qcmedical.ca        contact@qcmedical.ca
# 1  418.555.7766              qcmedical.ca                         NaN
# 2           NaN          obrien-clinic.ca  dr.obrien@obrien-clinic.ca
# 3  416-555-0000                       NaN                         NaN
# 4  519-555-1234        london-cardio-1.ca       info1@londoncardio.ca
# 5  519-555-1234           london-neuro.ca        info2@londonneuro.ca
# 6  519-555-9999         special-clinic.ca      info@special-clinic.ca
# 7  519-555-8888    whitespace-clinic.ca       contact@whitespace.ca
# 8  905-555-7777              UPPERCASE.CA           INFO@UPPERCASE.CA
# 9  519-555-6666              lowercase.ca           info@lowercase.ca
#
#                               notes
# 0                Bilingual services
# 1                  French & English
# 2                   No phone listed
# 3  Missing clinic name and location
# 4                               NaN
# 5               Same phone as above
# 6           Apostrophe, exclamation
# 7           Extra spaces everywhere
# 8                          ALL CAPS
# 9                     all lowercase

# %%
"""
STEP 1. Clean clinic_name, specialty, and city columns
- Apply clean_text() function on the 3 columns 
- The clean_text() function does the following:
    a. Checks if the input is a string
    b. Removes leading/trailing whitespace
    c. Standardizes capitalization - converts the string so each word starts with a capital letter
"""
df["clinic_name"] = df["clinic_name"].apply(clean_text)
df["specialty"] = df["specialty"].apply(clean_text)
df["city"] = df["city"].apply(clean_text)

df.head(10)
# Out:
#                  clinic_name         specialty         city province  \
# 0  Quebec City Medical Group   Family Medicine  Québec City       QC
# 1        Québec City Medical   Family Practice  Quebec City   Quebec
# 2       Dr. O'brien's Clinic  General Practice   St. John's       NL
# 3                       None   Massage Therapy         None      NaN
# 4     Duplicate Phone Test 1        Cardiology       London       ON
# 5     Duplicate Phone Test 2         Neurology       London  Ontario
# 6     Special Char's Clinic!       Urgent Care    Kitchener       ON
# 7          Whitespace Clinic     Ophthalmology     Waterloo       ON
# 8           Uppercase Clinic               Ent     Hamilton       ON
# 9           Lowercase Clinic          Oncology       Guelph       on
#
#           phone                   website                       email  \
# 0  418-555-7766          www.qcmedical.ca        contact@qcmedical.ca
# 1  418.555.7766              qcmedical.ca                         NaN
# 2           NaN          obrien-clinic.ca  dr.obrien@obrien-clinic.ca
# 3  416-555-0000                       NaN                         NaN
# 4  519-555-1234        london-cardio-1.ca       info1@londoncardio.ca
# 5  519-555-1234           london-neuro.ca        info2@londonneuro.ca
# 6  519-555-9999         special-clinic.ca      info@special-clinic.ca
# 7  519-555-8888    whitespace-clinic.ca       contact@whitespace.ca
# 8  905-555-7777              UPPERCASE.CA           INFO@UPPERCASE.CA
# 9  519-555-6666              lowercase.ca           info@lowercase.ca
#
#                               notes
# 0                Bilingual services
# 1                  French & English
# 2                   No phone listed
# 3  Missing clinic name and location
# 4                               NaN
# 5               Same phone as above
# 6           Apostrophe, exclamation
# 7           Extra spaces everywhere
# 8                          ALL CAPS
# 9                     all lowercase

# %%
"""
STEP 2. Clean province column
- Abbreviates Canadian provinces (i.e., Ontario becomes ON)
"""

df["province"] = df["province"].apply(normalize_province)
df.head(10)
# Out:
#                  clinic_name         specialty         city province  \
# 0  Quebec City Medical Group   Family Medicine  Québec City       QC
# 1        Québec City Medical   Family Practice  Quebec City       QC
# 2       Dr. O'brien's Clinic  General Practice   St. John's       NL
# 3                       None   Massage Therapy         None     None
# 4     Duplicate Phone Test 1        Cardiology       London       ON
# 5     Duplicate Phone Test 2         Neurology       London       ON
# 6     Special Char's Clinic!       Urgent Care    Kitchener       ON
# 7          Whitespace Clinic     Ophthalmology     Waterloo       ON
# 8           Uppercase Clinic               Ent     Hamilton       ON
# 9           Lowercase Clinic          Oncology       Guelph       ON
#
#           phone                   website                       email  \
# 0  418-555-7766          www.qcmedical.ca        contact@qcmedical.ca
# 1  418.555.7766              qcmedical.ca                         NaN
# 2           NaN          obrien-clinic.ca  dr.obrien@obrien-clinic.ca
# 3  416-555-0000                       NaN                         NaN
# 4  519-555-1234        london-cardio-1.ca       info1@londoncardio.ca
# 5  519-555-1234           london-neuro.ca        info2@londonneuro.ca
# 6  519-555-9999         special-clinic.ca      info@special-clinic.ca
# 7  519-555-8888    whitespace-clinic.ca       contact@whitespace.ca
# 8  905-555-7777              UPPERCASE.CA           INFO@UPPERCASE.CA
# 9  519-555-6666              lowercase.ca           info@lowercase.ca
#
#                               notes
# 0                Bilingual services
# 1                  French & English
# 2                   No phone listed
# 3  Missing clinic name and location
# 4                               NaN
# 5               Same phone as above
# 6           Apostrophe, exclamation
# 7           Extra spaces everywhere
# 8                          ALL CAPS
# 9                     all lowercase

# %%
"""
STEP 3. Clean phone column
- Standardizes phone numbers to include 10 digits (i.e., 123-456-7890 becomes 1234567890)
- Removes non-phone numbers from the phone column (sets them to `None`)
"""

df["phone"] = df["phone"].apply(clean_phone)
df.head(10)
# Out:
#                  clinic_name         specialty         city province  \
# 0  Quebec City Medical Group   Family Medicine  Québec City       QC
# 1        Québec City Medical   Family Practice  Quebec City       QC
# 2       Dr. O'brien's Clinic  General Practice   St. John's       NL
# 3                       None   Massage Therapy         None     None
# 4     Duplicate Phone Test 1        Cardiology       London       ON
# 5     Duplicate Phone Test 2         Neurology       London       ON
# 6     Special Char's Clinic!       Urgent Care    Kitchener       ON
# 7          Whitespace Clinic     Ophthalmology     Waterloo       ON
# 8           Uppercase Clinic               Ent     Hamilton       ON
# 9           Lowercase Clinic          Oncology       Guelph       ON
#
#         phone                   website                       email  \
# 0  4185557766          www.qcmedical.ca        contact@qcmedical.ca
# 1  4185557766              qcmedical.ca                         NaN
# 2        None          obrien-clinic.ca  dr.obrien@obrien-clinic.ca
# 3  4165550000                       NaN                         NaN
# 4  5195551234        london-cardio-1.ca       info1@londoncardio.ca
# 5  5195551234           london-neuro.ca        info2@londonneuro.ca
# 6  5195559999         special-clinic.ca      info@special-clinic.ca
# 7  5195558888    whitespace-clinic.ca       contact@whitespace.ca
# 8  9055557777              UPPERCASE.CA           INFO@UPPERCASE.CA
# 9  5195556666              lowercase.ca           info@lowercase.ca
#
#                               notes
# 0                Bilingual services
# 1                  French & English
# 2                   No phone listed
# 3  Missing clinic name and location
# 4                               NaN
# 5               Same phone as above
# 6           Apostrophe, exclamation
# 7           Extra spaces everywhere
# 8                          ALL CAPS
# 9                     all lowercase

# %%
"""
STEP 4. Clean website column
- Does the following:
    a. lowers the website url string
    b. if the url does not begin with `http`, append `https://` to start of website url
"""

df["website"] = df["website"].apply(clean_website)
df.head(10)
# Out:
#                  clinic_name         specialty         city province  \
# 0  Quebec City Medical Group   Family Medicine  Québec City       QC
# 1        Québec City Medical   Family Practice  Quebec City       QC
# 2       Dr. O'brien's Clinic  General Practice   St. John's       NL
# 3                       None   Massage Therapy         None     None
# 4     Duplicate Phone Test 1        Cardiology       London       ON
# 5     Duplicate Phone Test 2         Neurology       London       ON
# 6     Special Char's Clinic!       Urgent Care    Kitchener       ON
# 7          Whitespace Clinic     Ophthalmology     Waterloo       ON
# 8           Uppercase Clinic               Ent     Hamilton       ON
# 9           Lowercase Clinic          Oncology       Guelph       ON
#
#         phone                       website                       email  \
# 0  4185557766      https://www.qcmedical.ca        contact@qcmedical.ca
# 1  4185557766          https://qcmedical.ca                         NaN
# 2        None      https://obrien-clinic.ca  dr.obrien@obrien-clinic.ca
# 3  4165550000                          None                         NaN
# 4  5195551234    https://london-cardio-1.ca       info1@londoncardio.ca
# 5  5195551234       https://london-neuro.ca        info2@londonneuro.ca
# 6  5195559999     https://special-clinic.ca      info@special-clinic.ca
# 7  5195558888  https://whitespace-clinic.ca     contact@whitespace.ca
# 8  9055557777          https://uppercase.ca           INFO@UPPERCASE.CA
# 9  5195556666          https://lowercase.ca           info@lowercase.ca
#
#                               notes
# 0                Bilingual services
# 1                  French & English
# 2                   No phone listed
# 3  Missing clinic name and location
# 4                               NaN
# 5               Same phone as above
# 6           Apostrophe, exclamation
# 7           Extra spaces everywhere
# 8                          ALL CAPS
# 9                     all lowercase

# %%
"""
STEP 5. Clean email column
- cleans the emails by validating the string through a regular expression, if the email string is invalid, set to `None`
"""

df["email"] = df["email"].apply(clean_email)
df.head(10)
# Out:
#                  clinic_name         specialty         city province  \
# 0  Quebec City Medical Group   Family Medicine  Québec City       QC
# 1        Québec City Medical   Family Practice  Quebec City       QC
# 2       Dr. O'brien's Clinic  General Practice   St. John's       NL
# 3                       None   Massage Therapy         None     None
# 4     Duplicate Phone Test 1        Cardiology       London       ON
# 5     Duplicate Phone Test 2         Neurology       London       ON
# 6     Special Char's Clinic!       Urgent Care    Kitchener       ON
# 7          Whitespace Clinic     Ophthalmology     Waterloo       ON
# 8           Uppercase Clinic               Ent     Hamilton       ON
# 9           Lowercase Clinic          Oncology       Guelph       ON
#
#         phone                       website                       email  \
# 0  4185557766      https://www.qcmedical.ca        contact@qcmedical.ca
# 1  4185557766          https://qcmedical.ca                        None
# 2        None      https://obrien-clinic.ca  dr.obrien@obrien-clinic.ca
# 3  4165550000                          None                        None
# 4  5195551234    https://london-cardio-1.ca       info1@londoncardio.ca
# 5  5195551234       https://london-neuro.ca        info2@londonneuro.ca
# 6  5195559999     https://special-clinic.ca      info@special-clinic.ca
# 7  5195558888  https://whitespace-clinic.ca       contact@whitespace.ca
# 8  9055557777          https://uppercase.ca           info@uppercase.ca
# 9  5195556666          https://lowercase.ca           info@lowercase.ca
#
#                               notes
# 0                Bilingual services
# 1                  French & English
# 2                   No phone listed
# 3  Missing clinic name and location
# 4                               NaN
# 5               Same phone as above
# 6           Apostrophe, exclamation
# 7           Extra spaces everywhere
# 8                          ALL CAPS
# 9                     all lowercase

# %%
"""
STEP 6. Perform deduplication 
"""

# Performs deduplication for rows with matching `clinic_name` + `city`
df = df.drop_duplicates(subset=["clinic_name", "city"], keep='first')

# Performs additional deduplication by removing rows with duplicate phone numbers
df = df[df['phone'].isna() | ~df.duplicated(subset=['phone'], keep='first')]

# Performs deduplciation by removing rows with duplicate emails
df = df[df['email'].isna() | ~df.duplicated(subset=['email'], keep='first')]

df.head(10)
# Out:
#                           clinic_name         specialty         city province  \
# 0           Quebec City Medical Group   Family Medicine  Québec City       QC
# 2                Dr. O'brien's Clinic  General Practice   St. John's       NL
# 3                                None   Massage Therapy         None     None
# 4              Duplicate Phone Test 1        Cardiology       London       ON
# 6              Special Char's Clinic!       Urgent Care    Kitchener       ON
# 7                   Whitespace Clinic     Ophthalmology     Waterloo       ON
# 8                    Uppercase Clinic               Ent     Hamilton       ON
# 9                    Lowercase Clinic          Oncology       Guelph       ON
# 10  The Clinic (formerly Known As...)      Rheumatology      Windsor       ON
# 11                 Clinic With | Pipe           Urology       Sarnia       ON
#
#          phone                       website                       email  \
# 0   4185557766      https://www.qcmedical.ca        contact@qcmedical.ca
# 2         None      https://obrien-clinic.ca  dr.obrien@obrien-clinic.ca
# 3   4165550000                          None                        None
# 4   5195551234    https://london-cardio-1.ca       info1@londoncardio.ca
# 6   5195559999     https://special-clinic.ca      info@special-clinic.ca
# 7   5195558888  https://whitespace-clinic.ca       contact@whitespace.ca
# 8   9055557777          https://uppercase.ca           info@uppercase.ca
# 9   5195556666          https://lowercase.ca           info@lowercase.ca
# 10  5195555555         https://the-clinic.ca         admin@the-clinic.ca
# 11  5195554444        https://pipe-clinic.ca         info@pipe-clinic.ca
#
#                                notes
# 0                 Bilingual services
# 2                    No phone listed
# 3   Missing clinic name and location
# 4                                NaN
# 6            Apostrophe, exclamation
# 7            Extra spaces everywhere
# 8                           ALL CAPS
# 9                      all lowercase
# 10                       Name change
# 11            Special character test

# %%
"""
STEP 7. Remove missing essential fields (clinic_name, email)
- If the clinic_name or email is missing, drop the row
"""

df = df.dropna(subset=["clinic_name", "email"], how="any")
df.head(10)
# Out:
#                                           clinic_name         specialty  \
# 0                           Quebec City Medical Group   Family Medicine
# 2                                Dr. O'brien's Clinic  General Practice
# 4                              Duplicate Phone Test 1        Cardiology
# 6                              Special Char's Clinic!       Urgent Care
# 7                                   Whitespace Clinic     Ophthalmology
# 8                                    Uppercase Clinic               Ent
# 9                                    Lowercase Clinic          Oncology
# 10                  The Clinic (formerly Known As...)      Rheumatology
# 11                                 Clinic With | Pipe           Urology
# 12  Very Long Clinic Name That Goes On and On and ...   General Surgery
#
#            city province       phone                           website  \
# 0   Québec City       QC  4185557766          https://www.qcmedical.ca
# 2    St. John's       NL        None          https://obrien-clinic.ca
# 4        London       ON  5195551234        https://london-cardio-1.ca
# 6     Kitchener       ON  5195559999         https://special-clinic.ca
# 7      Waterloo       ON  5195558888      https://whitespace-clinic.ca
# 8      Hamilton       ON  9055557777              https://uppercase.ca
# 9        Guelph       ON  5195556666              https://lowercase.ca
# 10      Windsor       ON  5195555555             https://the-clinic.ca
# 11       Sarnia       ON  5195554444            https://pipe-clinic.ca
# 12      Sudbury       ON  7055553333  https://very-long-name-clinic.ca
#
#                                email                    notes
# 0               contact@qcmedical.ca       Bilingual services
# 2         dr.obrien@obrien-clinic.ca          No phone listed
# 4              info1@londoncardio.ca                      NaN
# 6             info@special-clinic.ca  Apostrophe, exclamation
# 7              contact@whitespace.ca  Extra spaces everywhere
# 8                  info@uppercase.ca                 ALL CAPS
# 9                  info@lowercase.ca            all lowercase
# 10               admin@the-clinic.ca              Name change
# 11               info@pipe-clinic.ca   Special character test
# 12  contact@very-long-name-clinic.ca              Length test

# %%
"""
STEP 8. Reorder rows and display cleaned data, set all null values to `None`
"""

df = df[["clinic_name", "specialty", "city", "province", "phone", "website", "email", "notes"]]
df = df.where(pd.notnull(df), None)
df.head(10)
# Out:
#                                           clinic_name         specialty  \
# 0                           Quebec City Medical Group   Family Medicine
# 2                                Dr. O'brien's Clinic  General Practice
# 4                              Duplicate Phone Test 1        Cardiology
# 6                              Special Char's Clinic!       Urgent Care
# 7                                   Whitespace Clinic     Ophthalmology
# 8                                    Uppercase Clinic               Ent
# 9                                    Lowercase Clinic          Oncology
# 10                  The Clinic (formerly Known As...)      Rheumatology
# 11                                 Clinic With | Pipe           Urology
# 12  Very Long Clinic Name That Goes On and On and ...   General Surgery
#
#            city province       phone                           website  \
# 0   Québec City       QC  4185557766          https://www.qcmedical.ca
# 2    St. John's       NL        None          https://obrien-clinic.ca
# 4        London       ON  5195551234        https://london-cardio-1.ca
# 6     Kitchener       ON  5195559999         https://special-clinic.ca
# 7      Waterloo       ON  5195558888      https://whitespace-clinic.ca
# 8      Hamilton       ON  9055557777              https://uppercase.ca
# 9        Guelph       ON  5195556666              https://lowercase.ca
# 10      Windsor       ON  5195555555             https://the-clinic.ca
# 11       Sarnia       ON  5195554444            https://pipe-clinic.ca
# 12      Sudbury       ON  7055553333  https://very-long-name-clinic.ca
#
#                                email                    notes
# 0               contact@qcmedical.ca       Bilingual services
# 2         dr.obrien@obrien-clinic.ca          No phone listed
# 4              info1@londoncardio.ca                     None
# 6             info@special-clinic.ca  Apostrophe, exclamation
# 7              contact@whitespace.ca  Extra spaces everywhere
# 8                  info@uppercase.ca                 ALL CAPS
# 9                  info@lowercase.ca            all lowercase
# 10               admin@the-clinic.ca              Name change
# 11               info@pipe-clinic.ca   Special character test
# 12  contact@very-long-name-clinic.ca              Length test
