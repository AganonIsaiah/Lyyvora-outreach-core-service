# %%
from rules_baseline_lead_scoring import load_leads, score_dataframe
 
 
 # Step 0. Load data from cleaned leads table
df = load_leads()
df
# Out:
#                    clinic_name         specialty            city province  \
# 0    Quebec City Medical Group   Family Medicine     Québec City       QC
# 1         Dr. O'Brien's Clinic  General Practice      St. John's       NL
# 2       Duplicate Phone Test 1        Cardiology         Calgary       AB
# 3       Special Char's Clinic!       Urgent Care       Vancouver       BC
# 4             Lowercase Clinic          Oncology          Guelph       ON
# ..                         ...               ...             ...      ...
# 165                Dr. ₹ Rupee         Neurology  Burleigh Falls       ON
# 166             Clinic ₽ Ruble        Cardiology       Gooderham       ON
# 167                  Dr. ₩ Won     Ophthalmology        Kinmount       ON
# 168            Clinic ₪ Shekel   Family Medicine          Minden       ON
# 169                Dr. ₦ Naira       Dermatology      Haliburton       ON
#
#           phone                     website                       email  \
# ...

# %%
# Step 1. Score data based on a rules-based approach
df = score_dataframe(df)
df
# Out:
#                  clinic_name          specialty            city province  \
# 148  Clinic in All Lowercase        Dermatology  North Kawartha       ON
# 32                  B Clinic        Dermatology     Bowmanville       ON
# 80             Select Clinic        Dermatology         Neebing       ON
# 169              Dr. ₦ Naira        Dermatology      Haliburton       ON
# 98                 Clinic //        Dermatology        Bergland       ON
# ..                       ...                ...             ...      ...
# 72             Dr. Anonymous  Internal Medicine   Dubreuilville       ON
# 76             Www.clinic.ca      Ophthalmology     Thunder Bay       ON
# 1       Dr. O'Brien's Clinic   General Practice      St. John's       NL
# 11         Email-only-clinic               None   Charlottetown       PE
# 73       Email Only Practice    Family Medicine         Nipigon       ON
#
#           phone                     website                       email  \
# ...
