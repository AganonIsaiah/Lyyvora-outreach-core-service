# %%
import pandas as pd

df = pd.read_csv(r"/home/isaie/Projects/Lyyvora-outreach-core-service/data/mock_data_sets/mock_dirty_data.csv")
df
# Out:
#                           clinic_name                     specialty  \
# 0             Dr. Sarah Chen's Clinic               Family Medicine
# 1    Dr. Sarah Chen - Family Practice               Family Medicine
# 2        Chen, Dr. Sarah (Family Med)               family medicine
# 3            Riverside Medical Centre                    Pediatrics
# 4            Riverside Medical Center                   Paediatrics
# 5        Thompson Chiropractic Clinic                  Chiropractic
# 6             Thompson's Chiropractic                  Chiropractor
# 7               Healthy Smiles Dental                     Dentistry
# 8         HealthySmiles Dental Clinic                        Dental
# 9            North York Physiotherapy                 Physiotherapy
# 10                  North York Physio              Physical Therapy
# 11        Martinez Dermatology Clinic                   Dermatology
# 12           Dr. Martinez Skin Clinic                   Dermatology
# ...
